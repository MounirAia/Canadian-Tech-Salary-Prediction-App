# %% [markdown]
# ## Good Ressource
# - https://github.com/solegalli/feature-engineering-for-machine-learning/tree/main/Section-08-Categorical-Encoding-Basic

# %% [markdown]
# I have several other files preprocessing the Canadian data from the stack overflow surveys that I use to train the model. However, I will not share them since it was done in the context of a college course, and thus I am scared that people might want to cheat on it.

# %%
import pandas as pd
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import joblib

# %%
basePath = ""

# %%
data = pd.read_csv(f"{basePath}/Project/Resources/CanadaData.csv")
data
# Out:
#                         OrgSize  \
# 0          500 to 999 employees
# 1            10 to 19 employees
# 2      1,000 to 4,999 employees
# 3          100 to 499 employees
# 4            20 to 99 employees
# ...                         ...
# 10242        10 to 19 employees
# 10243      100 to 499 employees
# 10244        20 to 99 employees
# 10245        10 to 19 employees
# 10246      100 to 499 employees
#
#                                                 Industry Experience  \
# 0      Information Services, IT, Software Development...        5-9
# 1      Information Services, IT, Software Development...        5-9
# 2      Information Services, IT, Software Development...       10-*
# 3         Manufacturing, Transportation, or Supply Chain       10-*
# 4      Information Services, IT, Software Development...        2-4
# ...                                                  ...        ...
# 10242  Information Services, IT, Software Development...       10-*
# 10243  Information Services, IT, Software Development...       10-*
# 10244  Information Services, IT, Software Development...       10-*
# 10245  Information Services, IT, Software Development...       10-*
# 10246  Information Services, IT, Software Development...       10-*
#
#                                                Title Country  \
# 0                                Developer, back-end  Canada
# 1      Data scientist or machine learning specialist  Canada
# 2                                Developer, back-end  Canada
# 3                              Developer, full-stack  Canada
# 4                              Developer, full-stack  Canada
# ...                                              ...     ...
# 10242  Developer, desktop or enterprise applications  Canada
# 10243                           Developer, front-end  Canada
# 10244                           Developer, front-end  Canada
# 10245                           Developer, front-end  Canada
# 10246                           Developer, front-end  Canada
#
#                                     City    Salary
# 0                        Edmonton Region  101490.0
# 1                         Halifax Region   52046.0
# 2                        Edmonton Region  118962.0
# 3                     North Shore Region   64686.0
# 4      Hamilton–Niagara Peninsula Region   59481.0
# ...                                  ...       ...
# 10242                    Edmonton Region  150000.0
# 10243    Lower Mainland–Southwest Region   90000.0
# 10244            Annapolis Valley Region   70000.0
# 10245                 Cape Breton Region   50000.0
# 10246                 Cape Breton Region   30000.0
#
# [10247 rows x 7 columns]

# %%
data = data.rename(columns={"OrgSize":"Company Size"})

# %%
experience_mapping = {
    '0-1': '0 to 1 years',
    '2-4': '2 to 4 years',
    '5-9': '5 to 9 years',
    '10-*': '10 or more years'
}

data['Experience'] = data['Experience'].map(experience_mapping)

data
# Out:
#                    Company Size  \
# 0          500 to 999 employees
# 1            10 to 19 employees
# 2      1,000 to 4,999 employees
# 3          100 to 499 employees
# 4            20 to 99 employees
# ...                         ...
# 10242        10 to 19 employees
# 10243      100 to 499 employees
# 10244        20 to 99 employees
# 10245        10 to 19 employees
# 10246      100 to 499 employees
#
#                                                 Industry        Experience  \
# 0      Information Services, IT, Software Development...      5 to 9 years
# 1      Information Services, IT, Software Development...      5 to 9 years
# 2      Information Services, IT, Software Development...  10 or more years
# 3         Manufacturing, Transportation, or Supply Chain  10 or more years
# 4      Information Services, IT, Software Development...      2 to 4 years
# ...                                                  ...               ...
# 10242  Information Services, IT, Software Development...  10 or more years
# 10243  Information Services, IT, Software Development...  10 or more years
# 10244  Information Services, IT, Software Development...  10 or more years
# 10245  Information Services, IT, Software Development...  10 or more years
# 10246  Information Services, IT, Software Development...  10 or more years
#
#                                                Title Country  \
# 0                                Developer, back-end  Canada
# 1      Data scientist or machine learning specialist  Canada
# 2                                Developer, back-end  Canada
# 3                              Developer, full-stack  Canada
# 4                              Developer, full-stack  Canada
# ...                                              ...     ...
# 10242  Developer, desktop or enterprise applications  Canada
# 10243                           Developer, front-end  Canada
# 10244                           Developer, front-end  Canada
# 10245                           Developer, front-end  Canada
# 10246                           Developer, front-end  Canada
#
#                                     City    Salary
# 0                        Edmonton Region  101490.0
# 1                         Halifax Region   52046.0
# 2                        Edmonton Region  118962.0
# 3                     North Shore Region   64686.0
# 4      Hamilton–Niagara Peninsula Region   59481.0
# ...                                  ...       ...
# 10242                    Edmonton Region  150000.0
# 10243    Lower Mainland–Southwest Region   90000.0
# 10244            Annapolis Valley Region   70000.0
# 10245                 Cape Breton Region   50000.0
# 10246                 Cape Breton Region   30000.0
#
# [10247 rows x 7 columns]

# %%
data.to_csv(f"{basePath}/ModifiedCanada.csv",index=False)

# %% [markdown]
# ## One Hot Encoding
# Encode each categorical variable into a vector of 00...00 and 1.
# The dimension of the vector is 1*n where n: number of columns,correspond to the number of unique values from the encoded columns.
#
# Good for Linear model and to not introduced some sort of hierarchy between categorical values.
#
# For example One hot encoding would be bad for value such as ["small","medium","large"]
#
# Since in this case you want to encode with some sort of hirarchy.

# %% [markdown]
# ### Creating the training and testing dataset

# %%
# I will drop the Country column because all my data is from Canada which make this column redundant.

data = data.drop(columns=["Country"])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop("Salary", axis=1),  # predictors
    data["Salary"],  # target
    test_size=0.2,  # percentage of obs in test set
    random_state=42,  # seed to ensure reproducibility
)

X_train.shape, X_test.shape
# Out:
# ((8197, 5), (2050, 5))

# %% [markdown]
# ### Using Scikit

# %%
encoder = OneHotEncoder(categories="auto",drop=None,sparse_output=False,handle_unknown="infrequent_if_exist")

encoder.set_output(transform="pandas")
# Out:
# OneHotEncoder(handle_unknown='infrequent_if_exist', sparse_output=False)

# %%
encoder.fit(X_train)
# Out:
# OneHotEncoder(handle_unknown='infrequent_if_exist', sparse_output=False)

# %%
encoder.transform(X_train).shape
# Out:
# (8197, 91)

# %%
encoder.transform(X_test).shape
# Out:
# (2050, 91)

# %% [markdown]
# #### Using Column Transformer

# %%
CompanySizeOrderedCategories = ['2 to 9 employees', '10 to 19 employees', '20 to 99 employees',
     '100 to 499 employees', '500 to 999 employees', '1,000 to 4,999 employees',
     '5,000 to 9,999 employees', '10,000 or more employees']

ExperienceOrderedCategories = ['0 to 1 years', '2 to 4 years', '5 to 9 years','10 or more years']
transformer = ColumnTransformer(
    transformers=[
        ('oe_CompanySize', OrdinalEncoder(categories=[CompanySizeOrderedCategories]),['Company Size']),
        ('oe_Experience', OrdinalEncoder(categories=[ExperienceOrderedCategories]), ['Experience']),
        ('categorical', OneHotEncoder(categories="auto",drop=None,sparse_output=False,handle_unknown="infrequent_if_exist"), ["Industry","Title","City"])
    ],remainder="passthrough")

transformer.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('oe_CompanySize',
#                                  OrdinalEncoder(categories=[['2 to 9 employees',
#                                                              '10 to 19 '
#                                                              'employees',
#                                                              '20 to 99 '
#                                                              'employees',
#                                                              '100 to 499 '
#                                                              'employees',
#                                                              '500 to 999 '
#                                                              'employees',
#                                                              '1,000 to 4,999 '
#                                                              'employees',
#                                                              '5,000 to 9,999 '
#                                                              'employees',
#                                                              '10,000 or more '
#                                                              'employees']]),
#                                  ['Company Size']),
#                                 ('oe_Experience',
#                                  OrdinalEncoder(categories=[['0 to 1 years',
#                                                              '2 to 4 years',
#                                                              '5 to 9 years',
#                                                              '10 or more '
#                                                              'years']]),
#                                  ['Experience']),
#                                 ('categorical',
#                                  OneHotEncoder(handle_unknown='infrequent_if_exist',
#                                                sparse_output=False),
#                                  ['Industry', 'Title', 'City'])])

# %%
transformer.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('oe_CompanySize',
#                                  OrdinalEncoder(categories=[['2 to 9 employees',
#                                                              '10 to 19 '
#                                                              'employees',
#                                                              '20 to 99 '
#                                                              'employees',
#                                                              '100 to 499 '
#                                                              'employees',
#                                                              '500 to 999 '
#                                                              'employees',
#                                                              '1,000 to 4,999 '
#                                                              'employees',
#                                                              '5,000 to 9,999 '
#                                                              'employees',
#                                                              '10,000 or more '
#                                                              'employees']]),
#                                  ['Company Size']),
#                                 ('oe_Experience',
#                                  OrdinalEncoder(categories=[['0 to 1 years',
#                                                              '2 to 4 years',
#                                                              '5 to 9 years',
#                                                              '10 or more '
#                                                              'years']]),
#                                  ['Experience']),
#                                 ('categorical',
#                                  OneHotEncoder(handle_unknown='infrequent_if_exist',
#                                                sparse_output=False),
#                                  ['Industry', 'Title', 'City'])])

# %%
X_train_enc = transformer.transform(X_train)
X_test_enc = transformer.transform(X_test)

X_test_enc.head(1)
# Out:
#       oe_CompanySize__Company Size  oe_Experience__Experience  \
# 5265                           3.0                        2.0
#
#       categorical__Industry_Advertising Services  \
# 5265                                         0.0
#
#       categorical__Industry_Financial Services  \
# 5265                                       0.0
#
#       categorical__Industry_Healthcare  \
# 5265                               0.0
#
#       categorical__Industry_Higher Education  \
# 5265                                     0.0
#
#       categorical__Industry_Information Services, IT, Software Development, or other Technology  \
# 5265                                                1.0
#
#       categorical__Industry_Insurance  categorical__Industry_Legal Services  \
# 5265                              0.0                                   0.0
#
#       categorical__Industry_Manufacturing, Transportation, or Supply Chain  \
# 5265                                                0.0
#
#       ...  categorical__City_Saint John–St. Stephen Region  \
# 5265  ...                                              0.0
#
#       categorical__City_Saskatoon–Biggar Region  \
# 5265                                        0.0
#
#       categorical__City_Southeast Region  categorical__City_Southern Region  \
# 5265                                 0.0                                0.0
#
#       categorical__City_Thompson–Okanagan Region  \
# 5265                                         0.0
#
#       categorical__City_Toronto Region  \
# 5265                               0.0
#
#       categorical__City_Vancouver Island and Coast Region  \
# 5265                                                0.0
#
#       categorical__City_West Coast–Northern Peninsula–Labrador Region  \
# 5265                                                0.0
#
#       categorical__City_Windsor-Sarnia Region  \
# 5265                                      1.0
#
#       categorical__City_Winnipeg Region
# 5265                                0.0
#
# [1 rows x 81 columns]

# %% [markdown]
# #### Pipeline Model Training

# %%
pipeline = Pipeline(steps=[('preprocessor', transformer),
                             ('regressor', LinearRegression())])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('oe_CompanySize',
#                                                   OrdinalEncoder(categories=[['2 '
#                                                                               'to '
#                                                                               '9 '
#                                                                               'employees',
#                                                                               '10 '
#                                                                               'to '
#                                                                               '19 '
#                                                                               'employees',
#                                                                               '20 '
#                                                                               'to '
#                                                                               '99 '
#                                                                               'employees',
#                                                                               '100 '
#                                                                               'to '
#                                                                               '499 '
#                                                                               'employees',
#                                                                               '500 '
#                                                                               'to '
#                                                                               '999 '
#                                                                               'employees',
#                                                                               '1,000 '
#                                                                               'to '
#                                                                               '4,999 '
#                                                                               'employees',
#                                                                               '5,000 '
#                                                                               'to '
#                                                                               '9,999 '
#                                                                               'employees',
#                                                                               '10,000 '
#                                                                               'or '
#                                                                               'more '
#                                                                               'employees']]),
#                                                   ['Company Size']),
#                                                  ('oe_Experience',
#                                                   OrdinalEncoder(categories=[['0 '
#                                                                               'to '
#                                                                               '1 '
#                                                                               'years',
#                                                                               '2 '
#                                                                               'to '
#                                                                               '4 '
#                                                                               'years',
#                                                                               '5 '
#                                                                               'to '
#                                                                               '9 '
#                                                                               'years',
#                                                                               '10 '
#                                                                               'or '
#                                                                               'more '
#                                                                               'years']]),
#                                                   ['Experience']),
#                                                  ('categorical',
#                                                   OneHotEncoder(handle_unknown='infrequent_if_exist',
#                                                                 sparse_output=False),
#                                                   ['Industry', 'Title',
#                                                    'City'])])),
#                 ('regressor', LinearRegression())])

# %%
predictions = pipeline.predict(X_test)
predictions
# Out:
# array([ 70348., 131204.,  60520., ...,  56000.,  70908.,  77580.])

# %%
Copy_X_test = X_test.copy()
Copy_X_test["Salary"] = y_test
Copy_X_test["Predicted Salary"] = predictions
Copy_X_test.head(5)
# Out:
#                   Company Size  \
# 5265      100 to 499 employees
# 2167  10,000 or more employees
# 9752  10,000 or more employees
# 5009  1,000 to 4,999 employees
# 9251      100 to 499 employees
#
#                                                Industry        Experience  \
# 5265  Information Services, IT, Software Development...      5 to 9 years
# 2167  Information Services, IT, Software Development...      5 to 9 years
# 9752  Information Services, IT, Software Development...      5 to 9 years
# 5009  Information Services, IT, Software Development...      5 to 9 years
# 9251                                     Legal Services  10 or more years
#
#                                               Title  \
# 5265                          Developer, QA or test
# 2167  Data scientist or machine learning specialist
# 9752                            Developer, back-end
# 5009  Developer, desktop or enterprise applications
# 9251                           Developer, front-end
#
#                                    City         Salary  Predicted Salary
# 5265              Windsor-Sarnia Region   86220.000000           70348.0
# 2167                     Calgary Region  187402.000000          131204.0
# 9752                 North Shore Region   55000.000000           60520.0
# 5009  Hamilton–Niagara Peninsula Region   83194.000000           95284.0
# 9251                 Cape Breton Region   53977.272727           53640.0

# %% [markdown]
# #### Analysing the Model Accuracy

# %%
mse = mean_squared_error(y_test, predictions)
math.sqrt(mse)
# Out:
# 30329021058224.336

# %%
mae = mean_absolute_error(y_test, predictions)
mae
# Out:
# 669856032218.2335

# %%
data["Company Size"].unique()
# Out:
# array(['500 to 999 employees', '10 to 19 employees',
#        '1,000 to 4,999 employees', '100 to 499 employees',
#        '20 to 99 employees', '10,000 or more employees',
#        '2 to 9 employees', '5,000 to 9,999 employees'], dtype=object)

# %% [markdown]
# #### Testing the Model With Custom Input

# %%
Company_Size = ['500 to 999 employees']*4
Experience = ['0 to 1 years', '2 to 4 years', '5 to 9 years','10 or more years']
Industry = ['Information Services, IT, Software Development, or other Technology']*4
Title = ['Developer, back-end']*4
City = ['Montréal Region']*4
testData = {
    'Company Size': Company_Size,
    'Experience': Experience,
    'Industry':Industry,
    'Title': Title,
    'City': City
}

testDF = pd.DataFrame(testData)
testDF
# Out:
#            Company Size        Experience  \
# 0  500 to 999 employees      0 to 1 years
# 1  500 to 999 employees      2 to 4 years
# 2  500 to 999 employees      5 to 9 years
# 3  500 to 999 employees  10 or more years
#
#                                             Industry                Title  \
# 0  Information Services, IT, Software Development...  Developer, back-end
# 1  Information Services, IT, Software Development...  Developer, back-end
# 2  Information Services, IT, Software Development...  Developer, back-end
# 3  Information Services, IT, Software Development...  Developer, back-end
#
#               City
# 0  Montréal Region
# 1  Montréal Region
# 2  Montréal Region
# 3  Montréal Region

# %%
(pipeline.predict(testDF)*1.33)/(12*4*5*8)
# Out:
# array([27.13754167, 38.73625   , 50.33772917, 61.9364375 ])

# %% [markdown]
# ### Exporting the Model

# %%
# joblib.dump(pipeline, f"{basePath}/Canada.joblib")
